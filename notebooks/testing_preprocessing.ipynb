# %%
import pandas as pd
import sys
sys.path.append('../src')

from preprocessing import preprocess_data

zhaw_complete, agroscope_complete = preprocess_data()

# Visualize
print(zhaw_complete.head())
print(agroscope_complete.head())

zhaw_complete.plot(x='timestring', y='Dryweight')
agroscope_complete.plot(x='timestring', y='Dryweight')
# Out:
# /Users/mirc/ZHAW/MLModel/microalgae-ml-model/notebooks/../src/preprocessing.py:14: UserWarning: Parsing dates in %d.%m.%Y %H:%M:%S.%f format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data[key] = pd.to_datetime(data[key])
# /Users/mirc/ZHAW/MLModel/microalgae-ml-model/notebooks/../src/preprocessing.py:14: UserWarning: Parsing dates in %d.%m.%Y %H:%M:%S.%f format when dayfirst=False (the default) was specified. Pass `dayfirst=True` or specify a format to silence this warning.
#   data[key] = pd.to_datetime(data[key])
#            timestring  FLOW.OF.ALGAE  FLOW.OF.CO2      PAR.1      PAR.2  \
# 0 2024-05-14 14:50:00      18.501160     0.381944  346.35420  546.87500
# 1 2024-05-14 15:00:00      18.357059     0.401042  418.31598  546.26737
# 2 2024-05-14 15:10:00      17.984954     0.410590  482.55211  613.02086
# 3 2024-05-14 15:20:00      18.079282     0.412326  394.79168  523.09031
# ...
